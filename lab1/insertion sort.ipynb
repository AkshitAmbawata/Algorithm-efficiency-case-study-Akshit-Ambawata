# %%
import time
import tracemalloc
import random
import sys

sys.setrecursionlimit(20000)

def insertion_sort(values):
    for i in range(1, len(values)):
        current = values[i]
        position = i - 1

        while position >= 0 and values[position] > current:
            values[position + 1] = values[position]
            position -= 1

        values[position + 1] = current

    return values


def run_automated_test(size, input_type):
    tracemalloc.start()
    
    if input_type == "Sorted":
        test_data = list(range(size))
    elif input_type == "Reverse-Sorted":
        test_data = list(range(size, 0, -1))
    elif input_type == "Random":
        test_data = random.sample(range(size * 10), size)
    
    start_time = time.time()
    insertion_sort(test_data) 
    
    end_time = time.time()
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    
    execution_time = end_time - start_time
    peak_memory_mb = peak / (1024 * 1024) 
    
    print(f"{input_type:<15} | Size: {size:<6} | Time: {execution_time:.6f}s | Peak Memory: {peak_memory_mb:.6f} MB")

print("Choose your execution mode:")
print("1: Manual Input (Type your own numbers)")
print("2: Automated Benchmark (Test all sizes & conditions)")
choice = input("Enter 1 or 2: ").strip()

if choice == "1":
    user_input = input("\nEnter numbers separated by spaces: ")
    data = list(map(int, user_input.split()))
    
    tracemalloc.start()
    start_time = time.time()
    
    sorted_data = insertion_sort(data)
    
    end_time = time.time()
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    
    print("\n--- Manual Run Results ---")
    print("Sorted list:", sorted_data)
    print(f"Time Taken  : {(end_time - start_time):.6f}s")
    print(f"Peak Memory : {(peak / (1024 * 1024)):.6f} MB")

elif choice == "2":
    input_sizes = [100, 500, 1000, 5000, 10000]
    input_types = ["Sorted", "Reverse-Sorted", "Random"]

    print("\nExecuting Insertion Sort benchmarks...\n")
    for size in input_sizes:
        for itype in input_types:
            run_automated_test(size, itype)
else:
    print("Invalid choice. Please re-run the cell and select 1 or 2.")
# Out:
# Choose your execution mode:
# 1: Manual Input (Type your own numbers)
# 2: Automated Benchmark (Test all sizes & conditions)
# Enter 1 or 2:  2
# Executing Insertion Sort benchmarks...
#
# Sorted          | Size: 100    | Time: 0.000024s | Peak Memory: 0.000816 MB
# Reverse-Sorted  | Size: 100    | Time: 0.000667s | Peak Memory: 0.000816 MB
# Random          | Size: 100    | Time: 0.000338s | Peak Memory: 0.028923 MB
# Sorted          | Size: 500    | Time: 0.000284s | Peak Memory: 0.008324 MB
# Reverse-Sorted  | Size: 500    | Time: 0.035024s | Peak Memory: 0.009064 MB
# Random          | Size: 500    | Time: 0.030265s | Peak Memory: 0.061455 MB
# Sorted          | Size: 1000   | Time: 0.000752s | Peak Memory: 0.027397 MB
# Reverse-Sorted  | Size: 1000   | Time: 0.235142s | Peak Memory: 0.031334 MB
# Random          | Size: 1000   | Time: 0.210696s | Peak Memory: 0.095940 MB
# Sorted          | Size: 5000   | Time: 0.005702s | Peak Memory: 0.182899 MB
# Reverse-Sorted  | Size: 5000   | Time: 5.773154s | Peak Memory: 0.182783 MB
# Random          | Size: 5000   | Time: 5.415365s | Peak Memory: 0.959068 MB
# Sorted          | Size: 10000  | Time: 0.010500s | Peak Memory: 0.370720 MB
# Reverse-Sorted  | Size: 10000  | Time: 40.318495s | Peak Memory: 0.377800 MB
# Random          | Size: 10000  | Time: 21.172768s | Peak Memory: 1.182905 MB
