# %%
import time
import tracemalloc
import random
import sys

sys.setrecursionlimit(20000)

def bubble_sort(values):
    n = len(values)
    for i in range(n):
        swapped = False
        for j in range(0, n - i - 1):
            if values[j] > values[j + 1]:
                values[j], values[j + 1] = values[j + 1], values[j]
                swapped = True
        if not swapped:
            break
    return values
    
def run_automated_test(size, input_type):
    tracemalloc.start()
    
    if input_type == "Sorted":
        test_data = list(range(size))
    elif input_type == "Reverse-Sorted":
        test_data = list(range(size, 0, -1))
    elif input_type == "Random":
        test_data = random.sample(range(size * 10), size)
    
    start_time = time.time()
    bubble_sort(test_data) 
    
    end_time = time.time()
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    
    execution_time = end_time - start_time
    peak_memory_mb = peak / (1024 * 1024) 
    
    print(f"{input_type:<15} | Size: {size:<6} | Time: {execution_time:.6f}s | Peak Memory: {peak_memory_mb:.6f} MB")

print("Choose your execution mode:")
print("1: Manual Input (Type your own numbers)")
print("2: Automated Benchmark (Test all sizes & conditions)")
choice = input("Enter 1 or 2: ").strip()

if choice == "1":
    user_input = input("\nEnter numbers separated by spaces: ")
    data = list(map(int, user_input.split()))
    
    tracemalloc.start()
    start_time = time.time()
    
    sorted_data = bubble_sort(data)
    
    end_time = time.time()
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    
    print("\n--- Manual Run Results ---")
    print("Sorted list:", sorted_data)
    print(f"Time Taken  : {(end_time - start_time):.6f}s")
    print(f"Peak Memory : {(peak / (1024 * 1024)):.6f} MB")

elif choice == "2":
    input_sizes = [100, 500, 1000, 5000, 10000]
    input_types = ["Sorted", "Reverse-Sorted", "Random"]

    print("\nExecuting Bubble Sort benchmarks...\n")
    for size in input_sizes:
        for itype in input_types:
            run_automated_test(size, itype)
else:
    print("Invalid choice. Please re-run the cell and select 1 or 2.")
# Out:
# Choose your execution mode:
# 1: Manual Input (Type your own numbers)
# 2: Automated Benchmark (Test all sizes & conditions)
# Enter 1 or 2:  2
# Executing Bubble Sort benchmarks...
#
# Sorted          | Size: 100    | Time: 0.000015s | Peak Memory: 0.000816 MB
# Reverse-Sorted  | Size: 100    | Time: 0.000884s | Peak Memory: 0.000816 MB
# Random          | Size: 100    | Time: 0.000715s | Peak Memory: 0.028526 MB
# Sorted          | Size: 500    | Time: 0.000236s | Peak Memory: 0.008324 MB
# Reverse-Sorted  | Size: 500    | Time: 0.083504s | Peak Memory: 0.009094 MB
# Random          | Size: 500    | Time: 0.067400s | Peak Memory: 0.061089 MB
# Sorted          | Size: 1000   | Time: 0.000648s | Peak Memory: 0.027397 MB
# Reverse-Sorted  | Size: 1000   | Time: 0.431642s | Peak Memory: 0.031355 MB
# Random          | Size: 1000   | Time: 0.438733s | Peak Memory: 0.095451 MB
# Sorted          | Size: 5000   | Time: 0.004137s | Peak Memory: 0.179985 MB
# Reverse-Sorted  | Size: 5000   | Time: 17.081586s | Peak Memory: 0.182951 MB
# Random          | Size: 5000   | Time: 12.417061s | Peak Memory: 0.959394 MB
# Sorted          | Size: 10000  | Time: 0.008170s | Peak Memory: 0.370720 MB
# Reverse-Sorted  | Size: 10000  | Time: 70.374831s | Peak Memory: 0.373688 MB
# Random          | Size: 10000  | Time: 53.472069s | Peak Memory: 1.182304 MB
